# %%
import pandas as pd

df = pd.read_csv("../dataset.csv")
for i in df.columns: 
    if i == "año": continue
    df[i] = df[i].str.replace("\n"," ")
    
df
# Out:
#             fuente                  busqueda  idioma  \
# 0   science direct       video games science  ingles
# 1   science direct       video games science  ingles
# 2   science direct       video games science  ingles
# 3   science direct       video games science  ingles
# 4   science direct       video games science  ingles
# 5   science direct       video games science  ingles
# 6   science direct       video games science  ingles
# 7   science direct       video games science  ingles
# 8   science direct       video games science  ingles
# 9   science direct     science in videogames  ingles
# 10  science direct     science in videogames  ingles
# 11  science direct     science in videogames  ingles
# 12  science direct     science in videogames  ingles
# 13  science direct     science in videogames  ingles
# 14           arxiv  video games and physics   ingles
# 15  google scholar  video games and physics   ingles
# 16  google scholar  video games and physics   ingles
# 17  google scholar  video games and physics   ingles
# 18  google scholar  video games and physics   ingles
# 19  science direct       science video games  ingles
# 20  science direct       science video games  ingles
#
#                                                   url  \
# 0   https://www.sciencedirect.com/science/article/...
# 1   https://www.sciencedirect.com/science/article/...
# 2   https://www.sciencedirect.com/science/article/...
# 3   https://www.sciencedirect.com/science/article/...
# 4   https://www.sciencedirect.com/science/article/...
# 5   https://www.sciencedirect.com/science/article/...
# 6   https://www.sciencedirect.com/science/article/...
# 7   https://www.sciencedirect.com/science/article/...
# 8   https://www.sciencedirect.com/science/article/...
# 9   https://www.sciencedirect.com/science/article/...
# 10  https://www.sciencedirect.com/science/article/...
# 11  https://www.sciencedirect.com/science/article/...
# 12  https://www.sciencedirect.com/science/article/...
# 13  https://www.sciencedirect.com/science/article/...
# 14                   https://arxiv.org/abs/1911.01864
# 15  https://iopscience.iop.org/article/10.1088/136...
# 16  https://pubs.aip.org/aip/acp/article-abstract/...
# 17  https://iopscience.iop.org/article/10.1088/003...
# 18  https://ieeexplore.ieee.org/abstract/document/...
# 19  https://www.sciencedirect.com/science/article/...
# 20  https://www.sciencedirect.com/science/article/...
#
#                                                titulo   año  \
# 0   Comparing effectiveness of educational video g...  2023
# 1   A Plea for Caution: Violent Video Games, the S...  2011
# 2   “It’s a terrible choice to make but also a nec...  2024
# 3   The role of video games in enhancing managers'...  2024
# 4   Impact of an active educational video game on ...  2016
# 5   Video gaming promotes concussion knowledge acq...  2006
# 6   Sustained decrease in oxygenated hemoglobin du...  2006
# 7   Video game values: Human–computer interaction ...  2007
# 8   High-resolution gaming: Interfaces, notificati...  2007
# 9   A Literature Review of How Videogames Are Asse...  2014
# 10  Opportunities to practice historical thinking ...  2022
# 11  Gender, videogames and navigation in virtual s...  2019
# 12  A full-body interactive videogame used as a to...  2019
# 13  Videogame Technology Re-Purposed: Towards Inte...  2015
# 14  The Physics of Fun: Quantifying Human Engageme...  2019
# 15  Informal physics learning from video games: a ...  2017
# 16  Improving physics instruction by analyzing vid...  2013
# 17  Gamification: using elements of video games to...  2016
# 18            Learning physics through computer games  2013
# 19  Two-dimensional representation of movement thr...  1994
# 20  Identifying video game addiction in children a...  1994
#
#                                               autores  \
# 0   Daniel López-Fernández ,  Aldo Gordillo ,  Raú...
# 1   Ryan C.W. Hall MD a ,  Terri Day JD, LLM, MSSA...
# 2                 Sophie Wright a ,  Alena Denisova b
# 3   Omid Ghasemi a ,  Mohammad Abooyee b ,  Somaye...
# 4                                 Haichun SunYong Gao
# 5          David GoodmanNori L. BradleyJames Bizzochi
# 6                            Goh Matsuda Kazuo Hiraki
# 7                 Pippin BarrJames NobleRobert Biddle
# 8            Andrew J Sabri Robert G Ball Chris North
# 9                                        Ron T. Brown
# 10            Taylor M. KessnerLauren McArthur Harris
# 11     Suzanne de CastellHector LariosJennifer Jenson
# 12  María Ángeles Mairenaa, Joan Mora-Guiardc, Lau...
# 13                                      Jules Moloney
# 14  David Reguera, Pol Colomer-de-Simón, Iván Enci...
# 15             DeVaughn Croxton1 and Gerd Kortemeyer1
# 16                                      Ian D. Beatty
# 17  J A Rose1, J M O'Meara1, T C Gerhardt3,2 and M...
# 18  Gary Hookway, Prof. Qasim Mehdi, Dr. Tom Hartl...
# 19  Patricia M. Greenfield ,  Craig Brannon ,  Dav...
# 20                                        Sue Fisher
#
#                                               resumen  \
# 0   Educational video games have been proven effec...
# 1   On November 2, 2010, the US Supreme Court hear...
# 2   Video games offer a unique platform for player...
# 3   Using gamification and video games is one of t...
# 4   Background Active educational video games (AVG...
# 5   While the positive uses for video games in an ...
# 6   Traditional neuroimaging studies have mainly f...
# 7   Current human–computer interaction (HCI) resea...
# 8   Advances in technology and display hardware ha...
# 9   In this paper the author explores how videogam...
# 10  Building on the education community’s longstan...
# 11  Spatial abilities associated with success in e...
# 12  Background: Game-based interventions that invo...
# 13  The author and associated researchers have in ...
# 14  Engaging in playful activities, such as playin...
# 15  Researching informal gameplay can be challengi...
# 16  Video games can be very powerful teaching syst...
# 17  Gamification has been extensively implemented ...
# 18  Physics today is not taught in a way that is e...
# 19  The anthropological study of games has demonst...
# 20  There is a current trend of thought among some...
#
#                                          introduccion  \
# 0   Over the millennia, humankind has advanced tha...
# 1   On November 2, 2010, the US Supreme Court hear...
# 2   Video games, as an interactive and expressive ...
# 3   Survival is contingent upon fulfilling environ...
# 4   The guidelines for physical activity (PA) for ...
# 5   The majority of recent work regarding computer...
# 6   Brain activity during a complex task correspon...
# 7   Video games are an extremely influential form ...
# 8   With the rapid development of technology, the ...
# 9   Since approximately 2008 gaming services in al...
# 10  History educators have long advocated a pedago...
# 11  Advancing our understanding of spatial abiliti...
# 12  Autism Spectrum Disorders (ASD) are serious ne...
# 13  Architectural design researchers have been app...
# 14  Humans are deeply captivated to try new experi...
# 15  Computer games have been explored as a means o...
# 16  In any domain, thinking outside of the histori...
# 17  The goal of a video-game developer is quite of...
# 18  Physics plays a role in all aspects of life an...
# 19  Cognitive processes-the basic processes by whi...
# 20  Coin-operated video game machines have become ...
#
#                                          conclusiones  \
# 0   This article has presented a research in the f...
# 1   The current debate about whether violence is c...
# 2   Our work offers insights into how video games ...
# 3   This study aimed to explore the relationship b...
# 4   In conclusion, the results of this study sugge...
# 5   In both Study 1 and 2, we demonstrated a posit...
# 6   Sustained oxyHb decrease in DPFC was observed ...
# 7   Video game HCI is an area with great potential...
# 8   By performing a controlled usability experimen...
# 9   Assessing videogames and gaming activities pre...
# 10  This study has implications for games research...
# 11  As we have noted, there is currently no standa...
# 12  The main purpose of this study was to conduct ...
# 13  While the above pilot study shows some promise...
# 14  We have seen that it is possible to quantify a...
# 15  Voluntarily produced gameplay videos with thei...
# 16  To me, themes of grounding, exploration, asses...
# 17  Students were more engaged when gamified techn...
# 18  The main aims of this paper were to create an ...
# 19  Although we were not able to demonstrate the p...
# 20  This study presents DSM-IV-JV, a preliminary s...
#
#                                           referencias
# 0   [1] UN General Assembly Transforming our world...
# 1   S Tisseron Videogames risks: diagnosis and man...
# 2   3909 LLC, 2013 3909 LLC Papers, please (2013) ...
# 3   [1] S. Singh, A. Chauhan, S. Dhir Analyzing th...
# 4   1 National Association for Sport and Physical ...
# 5   C.A. Anderson An update on the effects of play...
# 6   J.D. Allison, K.J. Meader, D.W. Loring, R.E. F...
# 7   O.W. Bertelsen et al. Activity theory E. Aarse...
# 8   Ball, R., North, C., 2005. An analysis of user...
# 9   Assessment (2014). In Merriam-Webster.com. Ret...
# 10  Bain R.B. Into the breach: Using research and ...
# 11  S. Ardener Women and space: Ground rules and s...
# 12  T.M. Achenbach, L.A. Rescorla Manual for the A...
# 13  [1] Lowe R, Hedley M, Goodwin R. Real-time por...
# 14  Hal R. Arkes and Catherine Blumer. The psychol...
# 15  [1] Bork A M 1975 Effective computer use in ph...
# 16  1. A. Amory, Education as Change 15, 111 (2011...
# 17  [1] Keller F S 1974 Ten years of personalized ...
# 18  [1] Autodesk (2013) 3ds Max 3D Modelling, Anim...
# 19  P.M. Greenfield et al. Cognitive socialization...
# 20  M.D. Griffiths Amusement machine playing in ch...

# %%
# %%time

nw = ["introduccion","conclusiones","referencias"]
sa = ["resumen","introduccion","conclusiones"]
ng = ["titulo","resumen","introduccion","conclusiones","referencias"]


import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
nw_dict = {}
for i in nw:
    nw_dict[i+"_nw"] = []
    for j,row in df.iterrows():
        tokens = word_tokenize(row[i])
        nw_dict[i+"_nw"].append(len(tokens))
        
        
        


from textblob import TextBlob
sa_dict = {}
for i in sa:
    sa_dict[i+"_sa"] = []
    for j,row in df.iterrows():
        text  = row[i]
        senti = TextBlob(text).sentiment
        sa_dict[i+"_sa"].append((senti.polarity,senti.subjectivity))
        

        
        
        
from itertools import islice
import spacy
from collections import Counter
nlp = spacy.load('en_core_web_sm')

def get_ngrams(text, n):
    doc = nlp(text)
    tokens = [token.lemma_.lower() for token in doc if not token.is_stop and not token.is_punct]
    remove_token = [" ","et","al"]
    tokens = [i for i in tokens if i not in remove_token]
    ngrams = zip(*[islice(tokens, i, None) for i in range(n)])
    return [" ".join(ngram) for ngram in ngrams]

ng_dict = {}
for i in ng:
    for n in range(1,4):
        ng_dict[i+"_ng"+str(n)] = []
        for j,row in df.iterrows():
            ngrams = get_ngrams(row[i], n)
            remove_ngram = ["video game","et al"]
            ngrams = [ngram for ngram in ngrams if ngram not in remove_ngram]
            ngrams = [ngram for ngram in ngrams if not any(substring in ngram for substring in remove_ngram)]
            ng_dict[i+"_ng"+str(n)].append(Counter(ngrams))

            
            
            
dataset = df.join(pd.DataFrame(nw_dict)).join(pd.DataFrame(sa_dict)).join(pd.DataFrame(ng_dict))
# Out:
# CPU times: user 19.7 s, sys: 343 ms, total: 20.1 s
# Wall time: 20.1 s

# %%
import matplotlib.pyplot as plt

ngram_freq = dataset["conclusiones_ng3"].sum() # Counter object
words, counts = zip(*ngram_freq.most_common(10))

# Create bar plot
plt.figure(figsize=(6, 5))
plt.barh(words, counts, color='blue')
plt.title(f'Top 10 Most Common {n}-grams')
plt.ylabel('N-grams')
plt.xlabel('Frequency')
# plt.xticks(rotation=90,fontsize=8)
plt.show()

# %%
dataset.columns
# Out:
# Index(['fuente', 'busqueda', 'idioma', 'url', 'titulo', 'año', 'autores',
#        'resumen', 'introduccion', 'conclusiones', 'referencias',
#        'introduccion_nw', 'conclusiones_nw', 'referencias_nw', 'resumen_sa',
#        'introduccion_sa', 'conclusiones_sa', 'titulo_ng1', 'titulo_ng2',
#        'titulo_ng3', 'resumen_ng1', 'resumen_ng2', 'resumen_ng3',
#        'introduccion_ng1', 'introduccion_ng2', 'introduccion_ng3',
#        'conclusiones_ng1', 'conclusiones_ng2', 'conclusiones_ng3',
#        'referencias_ng1', 'referencias_ng2', 'referencias_ng3'],
#       dtype='object')

# %%
bins = [1994,2000,2005,2010,2015,2020,2024]  # intervalos
dataset['year_group'] = pd.cut(dataset['año'], bins=bins, right=False)
grouped = dataset.groupby('year_group')['conclusiones_ng3'].sum()

grouped.index[5]
freq_to_plot = grouped[grouped.index[5]]

words, counts = zip(*freq_to_plot.most_common(10))

# Create bar plot
plt.figure(figsize=(8, 5))
plt.barh(words, counts, color='blue')
plt.title(f'Top 10 Most Common {n}-grams')
plt.ylabel('N-grams')
plt.xlabel('Frequency')
plt.show()
